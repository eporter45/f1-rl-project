# %%
import numpy as np
import pandas as pd
from pathlib import Path
import glob
import os
import shutil
import matplotlib.pyplot as plt

# Set project root dynamically
project_root = Path().resolve().parent
data_dir = project_root/'data'

# %%
# Load cleaned tyre data
tyre_dir = project_root /'cleaned_tyre_data'
tyre_list = glob.glob(str(tyre_dir / '*.csv'))
dfs_tyre = {Path(file).stem: pd.read_csv(file) for file in tyre_list}

print(f"Loaded {len(dfs_tyre)} cleaned tyre files")
data_list = glob.glob(str(data_dir / '*.csv'))
dfs_data = {Path(file).stem: pd.read_csv(file) for file in data_list}
# Out:
# Loaded 22 cleaned tyre files

# %%
# Load core race data
lap_times = dfs_data['lap_times']
races = dfs_data['races']
drivers = dfs_data['drivers']
'''print("Laptimes")
print(lap_times.head())
print("Races")
print(races.head())
print("Drivers")
print(drivers.head())'''
# Out:
# 'print("Laptimes")\nprint(lap_times.head())\nprint("Races")\nprint(races.head())\nprint("Drivers")\nprint(drivers.head())'

# %%
lap_times_copy = lap_times.copy()
times = lap_times_copy
print(times.keys())
# Out:
# Index(['raceId', 'driverId', 'lap', 'position', 'time', 'milliseconds'], dtype='object')

# %%
pit_stops = dfs_data['pit_stops']

# Filter for a specific driver and race
race_id = 926  # Example for 2015 Australia
driver_id = 1

pit_data = pit_stops.loc[
    (pit_stops['raceId'] == race_id) & 
    (pit_stops['driverId'] == driver_id)
]

print(pit_data[['stop', 'lap']])
# Out:
#       stop  lap
# 3834     1   25

# %%
def detect_pit_stops(lap_times, threshold=12000):
    # Pit stop → Large increase in lap time relative to previous lap
    pit_laps = []
    for i in range(1, len(lap_times)):
        if int(lap_times[i]) - int(lap_times[i-1]) > threshold:
            pit_laps.append(i + 1)  # Lap number is 1-based
    return pit_laps

# %%
def assign_tyre_data(df, tyre_data, threshold=12000):
    # ✅ Step 1: Identify if Supersoft is present for any driver in the race
    supersoft_present = any(
        'Super' in str(tyre_data.get(f'Stint {i}', '')).strip()
        for i in range(1, 5) 
        for idx in tyre_data.index
    )

    # ✅ Step 2: Define compound map based on presence of Supersoft
    if supersoft_present:
        compound_map = {
            'Supersoft': 'Soft',
            'Super': 'Soft',
            'Soft': 'Medium',
            'Medium': 'Hard',
            'Hard': 'Hard'
        }
    else:
        compound_map = {
            'Supersoft': 'Supersoft',
            'Super': 'Super',
            'Soft': 'Soft',
            'Medium': 'Medium',
            'Hard': 'Hard'
        }

    print(f"Compound map for this race: {compound_map}")

    # ✅ Step 3: Loop through each driver ID
    for driver_id in tyre_data['driverId'].unique():
        driver_stints = tyre_data.loc[tyre_data['driverId'] == driver_id].iloc[0]
        
        # ✅ Create a dictionary to hold stint info
        stint_map = {}
        for i in range(1, 5):
            stint_key = f'Stint {i}'
            stint_value = driver_stints.get(stint_key)  
            
            if pd.notna(stint_value) and isinstance(stint_value, str):  # ✅ Skip empty or NaN
                try:
                    compound, length = stint_value.split('(')
                    compound = compound.strip()
                    length = int(length.strip(')'))
                    
                    # ✅ Map using the adjusted compound map
                    compound = compound_map.get(compound.strip(), compound.strip())
                    stint_map[stint_key] = (compound, length)
                except ValueError:
                    print(f"⚠️ Invalid stint data for driver {driver_id} in {stint_key}: {stint_value}")
                    continue

        print(f"✅ Driver {driver_id} stint map: {stint_map}")

        # ✅ Step 4: Filter the lap data for the specific driver
        driver_laps = df.loc[df['driverId'] == driver_id].copy()

        # ✅ Step 5: Detect pit stops using stint length
        pit_laps = []
        current_lap = 1
        for stint_key in stint_map.keys():
            compound, stint_length = stint_map[stint_key]
            pit_lap = current_lap + stint_length
            if pit_lap <= driver_laps['lap'].max():
                # ✅ Search neighborhood of ±2 laps
                neighbor_window = driver_laps.loc[
                    (driver_laps['lap'] >= pit_lap - 2) &
                    (driver_laps['lap'] <= pit_lap + 2)
                ]
                if not neighbor_window.empty:
                    # ✅ Use .loc[] instead of .iloc[] to avoid IndexError
                    best_guess = neighbor_window.loc[neighbor_window['milliseconds'].idxmax(), 'lap']
                    pit_laps.append(best_guess)
                else:
                    pit_laps.append(pit_lap)
            current_lap = pit_lap + 1
        
        print(f"✅ Detected pit stops for driver {driver_id}: {pit_laps}")

        # ✅ Step 6: Assign compound and age using the stint_map
        stint_index = 0
        lap_counter = 1
        
        for idx in driver_laps.index:
            if stint_index < len(pit_laps) and driver_laps.loc[idx, 'lap'] == pit_laps[stint_index]:
                stint_index += 1
                lap_counter = 1
            
            stint_key = f'Stint {stint_index + 1}'
            if stint_key in stint_map:
                compound, stint_length = stint_map[stint_key]
                driver_laps.loc[idx, 'tyre_compound'] = compound
                driver_laps.loc[idx, 'tyre_age'] = lap_counter
            
            lap_counter += 1
        
        # ✅ Step 7: Save back into the original dataframe
        df.loc[df['driverId'] == driver_id] = driver_laps
    
    print(f"✅ `tyre_compound` and `tyre_age` successfully created.")
    return df

# %%
tyre_keys = list(dfs_tyre.keys())
tk = tyre_keys[0]
print(tyre_keys)
print(tk)
print(dfs_tyre[tk][dfs_tyre[tk]['driverId'] == 3])
# Out:
# ['948', '949', '928', '929', '939', '938', '936', '937', '934', '930', '931', '927', '933', '932', '926', '941', '940', '942', '943', '944', '950', '945']
# 948
#            NAME     Stint 1   Stint 2      Stint 3 Stint 4  driverId lastName
# 0  Nico Rosberg  Super (12)  Soft (6)  Medium (39)     NaN         3  rosberg

# %%
# Convert tyre_keys to integer (if necessary)
tkeys = [int(k) for k in tyre_keys]

# Filter the times dataframe to only include raceIds in tyre_keys
filtered_times = times[times['raceId'].isin(tkeys)].copy()
df = filtered_times
# Show the filtered dataframe
print(filtered_times.head(40))
print(f"Filtered times shape: {filtered_times.shape}")
# Out:
#        raceId  driverId  lap  position      time  milliseconds
# 90908     926         3   48         2  1:31.332         91332
# 90909     926         3   47         2  1:31.092         91092
# 90910     926         3   46         2  1:31.319         91319
# 90911     926         3   45         2  1:31.231         91231
# 90912     926         3   44         2  1:32.243         92243
# 90913     926         3   43         2  1:31.259         91259
# 90914     926         3   42         2  1:31.493         91493
# 90915     926         3   41         2  1:31.400         91400
# 90916     926         3   40         2  1:31.798         91798
# 90917     926         3   39         2  1:31.565         91565
# 90918     926         3   38         2  1:31.573         91573
# 90919     926         3   37         2  1:31.610         91610
# 90920     926         3   36         2  1:31.355         91355
# 90921     926         3   35         2  1:31.775         91775
# 90922     926         3   34         2  1:32.981         92981
# 90923     926         3   33         2  1:31.660         91660
# 90924     926         3   32         2  1:31.737         91737
# 90925     926         3   31         2  1:31.609         91609
# 90926     926         3   30         2  1:31.754         91754
# 90927     926         3   29         2  1:32.108         92108
# 90928     926         3   28         2  1:32.092         92092
# 90929     926         3   27         2  1:38.552         98552
# 90930     926         3   26         1  1:51.568        111568
# 90931     926         3   25         1  1:33.964         93964
# 90932     926         3   24         2  1:33.048         93048
# 90933     926         3   23         2  1:32.948         92948
# 90934     926         3   22         2  1:33.011         93011
# 90935     926         3   21         2  1:32.454         92454
# 90936     926         3   20         2  1:32.426         92426
# 90937     926         3   19         2  1:32.243         92243
# 90938     926         3   18         2  1:32.365         92365
# 90939     926         3   17         2  1:32.300         92300
# 90940     926         3   16         2  1:32.324         92324
# 90941     926         3   15         2  1:33.576         93576
# 90942     926         3   14         2  1:32.930         92930
# 90943     926         3   13         2  1:32.752         92752
# 90944     926         3   12         2  1:32.650         92650
# 90945     926         3   11         2  1:33.184         93184
# 90946     926         3   10         2  1:32.572         92572
# 90947     926         3    9         2  1:32.380         92380
# Filtered times shape: (23097, 6)

# %%
df_copy = df
# Create a mapping from raceId to circuitId using the races dataframe
race_to_circuit_map = races.set_index('raceId')['circuitId'].to_dict()
# Add circuitId to filtered_times by mapping raceId
df_copy['circuitId'] = df_copy['raceId'].map(race_to_circuit_map)
# Show the updated dataframe
print(df_copy.head(10))
# Out:
#        raceId  driverId  lap  position      time  milliseconds  circuitId
# 90908     926         3   48         2  1:31.332         91332          1
# 90909     926         3   47         2  1:31.092         91092          1
# 90910     926         3   46         2  1:31.319         91319          1
# 90911     926         3   45         2  1:31.231         91231          1
# 90912     926         3   44         2  1:32.243         92243          1
# 90913     926         3   43         2  1:31.259         91259          1
# 90914     926         3   42         2  1:31.493         91493          1
# 90915     926         3   41         2  1:31.400         91400          1
# 90916     926         3   40         2  1:31.798         91798          1
# 90917     926         3   39         2  1:31.565         91565          1

# %%
# Select a single race for testing
test_race_id = '948'

# Get lap data for that race
test_data = df_copy.loc[df_copy['raceId'] == int(test_race_id)].copy()

# ✅ Step 1: Ensure lap time column exists
if 'lapTime' not in test_data.columns:
    for alt_name in ['time', 'laptime', 'milliseconds']:
        if alt_name in test_data.columns:
            test_data.rename(columns={alt_name: 'lapTime'}, inplace=True)
            break

# ✅ Step 2: Get tyre data for that race
if test_race_id in tyre_data.keys():
    tyre_info = tyre_data[test_race_id]
    
    if not tyre_info.empty:
        print(f"Tyre info for race {test_race_id} loaded:")
        print(tyre_info)

        # ✅ Step 3: Apply tyre compound and age logic
        test_data = assign_tyre_data(test_data, tyre_info)

        # ✅ Step 4: Ensure the function actually returned a dataframe
        if test_data is not None and isinstance(test_data, pd.DataFrame):
            # ✅ Check that columns were created correctly
            if 'tyre_compound' in test_data.columns and 'tyre_age' in test_data.columns:
                print(f"✅ Tyre data successfully added for race {test_race_id}")
                print(test_data[['raceId', 'lap', 'tyre_compound', 'tyre_age']])
            else:
                print(f"⚠️ Tyre compound or age columns not created for race {test_race_id}.")
        else:
            print(f"⚠️ Tyre compound or age columns not created for race {test_race_id}.")
    else:
        print(f"⚠️ No tyre data found for race {test_race_id}.")
else:
    print(f"⚠️ No tyre data available for race ID {test_race_id}.")
# Out:
# Tyre info for race 948 loaded:
#                  NAME     Stint 1      Stint 2      Stint 3      Stint 4  \
# 0        Nico Rosberg  Super (12)     Soft (6)  Medium (39)          NaN
# 1      Lewis Hamilton  Super (16)  Medium (41)          NaN          NaN
# 2    Sebastian Vettel  Super (13)   Super (22)    Soft (22)          NaN
# 3    Daniel Ricciardo  Super (12)    Super (6)    Soft (24)   Super (15)
# 4        Felipe Massa  Super (11)     Soft (7)  Medium (39)          NaN
# 5     Romain Grosjean   Soft (18)  Medium (39)          NaN          NaN
# 6     Nico Hulkenberg   Soft (16)  Medium (41)          NaN          NaN
# 7     Valtteri Bottas   Soft (17)  Medium (40)          NaN          NaN
# 8    Carlos Sainz Jnr   Super (8)    Soft (10)    Soft (13)  Medium (26)
# 9      Max Verstappen  Super (13)     Soft (5)    Soft (14)  Medium (25)
# 10      Jolyon Palmer  Super (12)     Soft (6)  Medium (39)          NaN
# 11    Kevin Magnussen   Super (1)    Soft (17)  Medium (39)          NaN
# 12       Sergio Perez   Soft (16)  Medium (41)          NaN          NaN
# 13      Jenson Button   Soft (15)     Soft (3)   Super (12)  Medium (26)
# 14        Felipe Nasr  Super (10)     Soft (8)  Medium (38)          NaN
# 15    Pascal Wehrlein  Super (11)     Soft (7)    Soft (14)  Medium (24)
# 16    Marcus Ericsson  Super (11)     Soft (7)  Medium (20)          NaN
# 17     Kimi Raikkonen  Super (16)    Super (5)          NaN          NaN
# 18       Rio Haryanto  Super (12)     Soft (5)          NaN          NaN
# 19  Esteban Gutierrez   Soft (16)          NaN          NaN          NaN
# 20    Fernando Alonso  Super (12)     Soft (4)          NaN          NaN
#
#     driverId    lastName
# 0          3     rosberg
# 1          1    hamilton
# 2         20      vettel
# 3        817   ricciardo
# 4         13       massa
# 5        154    grosjean
# 6        807  hulkenberg
# 7        822      bottas
# 8        832         jnr
# 9        830  verstappen
# 10       835      palmer
# 11       825   magnussen
# 12       815       perez
# 13        18      button
# 14       831        nasr
# 15       836    wehrlein
# 16       828    ericsson
# 17         8   raikkonen
# 18       837    haryanto
# 19       821   gutierrez
# 20         4      alonso
# Compound map for this race: {'Supersoft': 'Soft', 'Super': 'Soft', 'Soft': 'Medium', 'Medium': 'Hard', 'Hard': 'Hard'}
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 6), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 3: [np.int64(12), np.int64(19)]
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 1: [np.int64(18)]
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 22), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 20: [np.int64(13), np.int64(35)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Soft', 6), 'Stint 3': ('Medium', 24), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 817: [np.int64(12), np.int64(19), np.int64(43)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 13: [np.int64(11), np.int64(18)]
# ✅ Driver 154 stint map: {'Stint 1': ('Medium', 18), 'Stint 2': ('Hard', 39)}
# ✅ Detected pit stops for driver 154: [np.int64(18)]
# ✅ Driver 807 stint map: {'Stint 1': ('Medium', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 807: [np.int64(18)]
# ✅ Driver 822 stint map: {'Stint 1': ('Medium', 17), 'Stint 2': ('Hard', 40)}
# ✅ Detected pit stops for driver 822: [np.int64(18)]
# ✅ Driver 832 stint map: {'Stint 1': ('Soft', 8), 'Stint 2': ('Medium', 10), 'Stint 3': ('Medium', 13), 'Stint 4': ('Hard', 26)}
# ✅ Detected pit stops for driver 832: [np.int64(8), np.int64(18), np.int64(32)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 5), 'Stint 3': ('Medium', 14), 'Stint 4': ('Hard', 25)}
# ✅ Detected pit stops for driver 830: [np.int64(13), np.int64(19), np.int64(33)]
# ✅ Driver 835 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 6), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 835: [np.int64(12), np.int64(18)]
# ✅ Driver 825 stint map: {'Stint 1': ('Soft', 1), 'Stint 2': ('Medium', 17), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 825: [np.int64(1), np.int64(18)]
# ✅ Driver 815 stint map: {'Stint 1': ('Medium', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 815: [np.int64(18)]
# ✅ Driver 18 stint map: {'Stint 1': ('Medium', 15), 'Stint 2': ('Medium', 3), 'Stint 3': ('Soft', 12), 'Stint 4': ('Hard', 26)}
# ✅ Detected pit stops for driver 18: [np.int64(18), np.int64(18), np.int64(31)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 8), 'Stint 3': ('Hard', 38)}
# ✅ Detected pit stops for driver 831: [np.int64(10), np.int64(18)]
# ✅ Driver 836 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Medium', 14), 'Stint 4': ('Hard', 24)}
# ✅ Detected pit stops for driver 836: [np.int64(11), np.int64(18), np.int64(33)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Hard', 20)}
# ✅ Detected pit stops for driver 828: [np.int64(11), np.int64(18)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Soft', 5)}
# ✅ Detected pit stops for driver 8: [np.int64(19)]
# ✅ Driver 837 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 5)}
# ✅ Detected pit stops for driver 837: [np.int64(12)]
# ✅ Driver 821 stint map: {'Stint 1': ('Medium', 16)}
# ✅ Detected pit stops for driver 821: []
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 4)}
# ✅ Detected pit stops for driver 4: [np.int64(12)]
# ✅ `tyre_compound` and `tyre_age` successfully created.
# ⚠️ Tyre compound or age columns not created for race 948.

# %%
print(tyre_data.keys())
tyre_race_ids = tyre_data['948'].keys()
print(tyre_race_ids)
print(df_copy.keys())
# Out:
# dict_keys(['948', '949', '928', '929', '939', '938', '936', '937', '934', '930', '931', '927', '933', '932', '926', '941', '940', '942', '943', '944', '950', '945'])
# Index(['NAME', 'Stint 1', 'Stint 2', 'Stint 3', 'Stint 4', 'driverId',
#        'lastName'],
#       dtype='object')
# Index(['raceId', 'driverId', 'lap', 'position', 'time', 'milliseconds',
#        'circuitId'],
#       dtype='object')

# %%
print(test_data.head(57))
# Out:
#         raceId  driverId  lap  position    lapTime  milliseconds  circuitId  \
# 111775     948        20    1         1   1:36.916         96916          1
# 111776     948        20    2         1   1:31.664         91664          1
# 111777     948        20    3         1   1:32.167         92167          1
# 111778     948        20    4         1   1:32.014         92014          1
# 111779     948        20    5         1   1:32.273         92273          1
# 111780     948        20    6         1   1:32.204         92204          1
# 111781     948        20    7         1   1:32.080         92080          1
# 111782     948        20    8         1   1:32.289         92289          1
# 111783     948        20    9         1   1:32.578         92578          1
# 111784     948        20   10         1   1:32.571         92571          1
# 111785     948        20   11         1   1:32.960         92960          1
# 111786     948        20   12         1   1:33.014         93014          1
# 111787     948        20   13         3   1:50.574        110574          1
# 111788     948        20   14         3   1:35.604         95604          1
# 111789     948        20   15         3   1:30.757         90757          1
# 111790     948        20   16         1   1:31.809         91809          1
# 111791     948        20   17         1   1:39.423         99423          1
# 111792     948        20   18         1   3:21.551        201551          1
# 111793     948        20   19         1  20:13.527       1213527          1
# 111794     948        20   20         1   1:30.524         90524          1
# 111795     948        20   21         1   1:30.374         90374          1
# 111796     948        20   22         1   1:30.207         90207          1
# 111797     948        20   23         1   1:29.951         89951          1
# 111798     948        20   24         1   1:30.185         90185          1
# 111799     948        20   25         1   1:30.719         90719          1
# 111800     948        20   26         1   1:31.764         91764          1
# 111801     948        20   27         1   1:31.454         91454          1
# 111802     948        20   28         1   1:31.507         91507          1
# 111803     948        20   29         1   1:31.809         91809          1
# 111804     948        20   30         1   1:32.003         92003          1
# 111805     948        20   31         1   1:32.228         92228          1
# 111806     948        20   32         1   1:32.227         92227          1
# 111807     948        20   33         1   1:32.795         92795          1
# 111808     948        20   34         1   1:32.937         92937          1
# 111809     948        20   35         4   1:53.109        113109          1
# 111810     948        20   36         4   1:34.747         94747          1
# 111811     948        20   37         4   1:30.251         90251          1
# 111812     948        20   38         4   1:30.612         90612          1
# 111813     948        20   39         4   1:30.627         90627          1
# 111814     948        20   40         4   1:31.064         91064          1
# 111815     948        20   41         4   1:31.220         91220          1
# 111816     948        20   42         3   1:31.104         91104          1
# 111817     948        20   43         3   1:30.814         90814          1
# 111818     948        20   44         3   1:31.196         91196          1
# 111819     948        20   45         3   1:30.779         90779          1
# 111820     948        20   46         3   1:30.725         90725          1
# 111821     948        20   47         3   1:30.590         90590          1
# 111822     948        20   48         3   1:30.463         90463          1
# 111823     948        20   49         3   1:30.271         90271          1
# 111824     948        20   50         3   1:30.168         90168          1
# 111825     948        20   51         3   1:30.137         90137          1
# 111826     948        20   52         3   1:31.262         91262          1
# 111827     948        20   53         3   1:30.665         90665          1
# 111828     948        20   54         3   1:30.907         90907          1
# 111829     948        20   55         3   1:35.239         95239          1
# 111830     948        20   56         3   1:30.965         90965          1
# 111831     948        20   57         3   1:31.634         91634          1
#
#        tyre_compound tyre_age
# 111775          Soft        1
# 111776          Soft        2
# 111777          Soft        3
# 111778          Soft        4
# 111779          Soft        5
# 111780          Soft        6
# 111781          Soft        7
# 111782          Soft        8
# 111783          Soft        9
# 111784          Soft       10
# 111785          Soft       11
# 111786          Soft       12
# 111787          Soft        1
# 111788          Soft        2
# 111789          Soft        3
# 111790          Soft        4
# 111791          Soft        5
# 111792          Soft        6
# 111793          Soft        7
# 111794          Soft        8
# 111795          Soft        9
# 111796          Soft       10
# 111797          Soft       11
# 111798          Soft       12
# 111799          Soft       13
# 111800          Soft       14
# 111801          Soft       15
# 111802          Soft       16
# 111803          Soft       17
# 111804          Soft       18
# 111805          Soft       19
# 111806          Soft       20
# 111807          Soft       21
# 111808          Soft       22
# 111809        Medium        1
# 111810        Medium        2
# 111811        Medium        3
# 111812        Medium        4
# 111813        Medium        5
# 111814        Medium        6
# 111815        Medium        7
# 111816        Medium        8
# 111817        Medium        9
# 111818        Medium       10
# 111819        Medium       11
# 111820        Medium       12
# 111821        Medium       13
# 111822        Medium       14
# 111823        Medium       15
# 111824        Medium       16
# 111825        Medium       17
# 111826        Medium       18
# 111827        Medium       19
# 111828        Medium       20
# 111829        Medium       21
# 111830        Medium       22
# 111831          None     None

# %%
test_id = '937'
tyre_ex = tyre_data[test_id]
print(tyre_ex)
# Out:
#           Unnamed: 0      Stint 1      Stint 2      Stint 3    Stint 4
# 0     Lewis Hamilton    Soft (13)  Medium (17)    Soft (13)        NaN
# 1       Nico Rosberg    Soft (12)  Medium (19)    Soft (12)        NaN
# 2    Romain Grosjean     Soft (9)    Soft (12)  Medium (22)        NaN
# 3       Daniil Kvyat     Soft (9)  Medium (18)    Soft (16)        NaN
# 4       Sergio Perez     Soft (8)    Soft (12)  Medium (23)        NaN
# 5       Felipe Massa     Soft (9)  Medium (12)  Medium (22)        NaN
# 6     Kimi Raikkonen    Soft (11)    Soft (10)  Medium (22)        NaN
# 7     Max Verstappen     Soft (9)    Soft (12)  Medium (11)  Soft (11)
# 8    Valtteri Bottas     Soft (8)    Soft (13)  Medium (22)        NaN
# 9    Marcus Ericsson     Soft (9)  Medium (19)    Soft (15)        NaN
# 10       Felipe Nasr  Medium (10)    Soft (17)    Soft (16)        NaN
# 11  Sebastian Vettel    Soft (14)  Medium (28)          NaN        NaN
# 12   Fernando Alonso   Medium (8)    Soft (12)    Soft (12)  Soft (10)
# 13     Jenson Button  Medium (11)     Soft (9)    Soft (15)   Soft (7)
# 14     Roberto Merhi    Soft (15)    Soft (14)  Medium (13)        NaN
# 15      Will Stevens    Soft (16)    Soft (14)  Medium (12)        NaN
# 16  Carlos Sainz Jnr     Soft (5)  Medium (18)     Soft (9)        NaN
# 17  Daniel Ricciardo     Soft (7)  Medium (12)          NaN        NaN
# 18  Pastor Maldonado     Soft (2)          NaN          NaN        NaN
# 19   Nico Hulkenberg          NaN          NaN          NaN        NaN

# %%
# ✅ Create a dictionary to store processed data by raceId
processed_data_by_race = {}

# ✅ Loop through all tyre datasets
for race_id, tyre_info in tyre_data.items():
    print(f"Processing Race ID {race_id}...")
    
    # ✅ Get lap data for that race
    race_data = lap_times_copy.loc[lap_times_copy['raceId'] == int(race_id)].copy()
    
    if not race_data.empty and not tyre_info.empty:
        result = assign_tyre_data(race_data, tyre_info)
        if result is not None:
            processed_data_by_race[race_id] = result
    else:
        print(f"⚠️ No valid lap data or tyre info for race {race_id}")

# ✅ Final check
for race_id, data in processed_data_by_race.items():
    print(f"✅ Processed data for race {race_id}: {data.shape}")
# Out:
# Processing Race ID 948...
# Compound map for this race: {'Supersoft': 'Soft', 'Super': 'Soft', 'Soft': 'Medium', 'Medium': 'Hard', 'Hard': 'Hard'}
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 6), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 3: [np.int64(12), np.int64(19)]
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 1: [np.int64(18)]
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 22), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 20: [np.int64(13), np.int64(35)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Soft', 6), 'Stint 3': ('Medium', 24), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 817: [np.int64(12), np.int64(19), np.int64(43)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 13: [np.int64(11), np.int64(18)]
# ✅ Driver 154 stint map: {'Stint 1': ('Medium', 18), 'Stint 2': ('Hard', 39)}
# ✅ Detected pit stops for driver 154: [np.int64(18)]
# ✅ Driver 807 stint map: {'Stint 1': ('Medium', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 807: [np.int64(18)]
# ✅ Driver 822 stint map: {'Stint 1': ('Medium', 17), 'Stint 2': ('Hard', 40)}
# ✅ Detected pit stops for driver 822: [np.int64(18)]
# ✅ Driver 832 stint map: {'Stint 1': ('Soft', 8), 'Stint 2': ('Medium', 10), 'Stint 3': ('Medium', 13), 'Stint 4': ('Hard', 26)}
# ✅ Detected pit stops for driver 832: [np.int64(8), np.int64(18), np.int64(32)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 5), 'Stint 3': ('Medium', 14), 'Stint 4': ('Hard', 25)}
# ✅ Detected pit stops for driver 830: [np.int64(13), np.int64(19), np.int64(33)]
# ✅ Driver 835 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 6), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 835: [np.int64(12), np.int64(18)]
# ✅ Driver 825 stint map: {'Stint 1': ('Soft', 1), 'Stint 2': ('Medium', 17), 'Stint 3': ('Hard', 39)}
# ✅ Detected pit stops for driver 825: [np.int64(1), np.int64(18)]
# ✅ Driver 815 stint map: {'Stint 1': ('Medium', 16), 'Stint 2': ('Hard', 41)}
# ✅ Detected pit stops for driver 815: [np.int64(18)]
# ✅ Driver 18 stint map: {'Stint 1': ('Medium', 15), 'Stint 2': ('Medium', 3), 'Stint 3': ('Soft', 12), 'Stint 4': ('Hard', 26)}
# ✅ Detected pit stops for driver 18: [np.int64(18), np.int64(18), np.int64(31)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 8), 'Stint 3': ('Hard', 38)}
# ✅ Detected pit stops for driver 831: [np.int64(10), np.int64(18)]
# ✅ Driver 836 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Medium', 14), 'Stint 4': ('Hard', 24)}
# ✅ Detected pit stops for driver 836: [np.int64(11), np.int64(18), np.int64(33)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 7), 'Stint 3': ('Hard', 20)}
# ✅ Detected pit stops for driver 828: [np.int64(11), np.int64(18)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Soft', 5)}
# ✅ Detected pit stops for driver 8: [np.int64(19)]
# ✅ Driver 837 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 5)}
# ✅ Detected pit stops for driver 837: [np.int64(12)]
# ✅ Driver 821 stint map: {'Stint 1': ('Medium', 16)}
# ✅ Detected pit stops for driver 821: []
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 4)}
# ✅ Detected pit stops for driver 4: [np.int64(12)]
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 949...
# Compound map for this race: {'Supersoft': 'Soft', 'Super': 'Soft', 'Soft': 'Medium', 'Medium': 'Hard', 'Hard': 'Hard'}
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 17), 'Stint 3': ('Soft', 9), 'Stint 4': ('Medium', 18)}
# ✅ Detected pit stops for driver 3: [np.int64(14), np.int64(31), np.int64(40)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 17), 'Stint 3': ('Soft', 8), 'Stint 4': ('Medium', 20)}
# ✅ Detected pit stops for driver 8: [np.int64(13), np.int64(30), np.int64(38)]
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Hard', 15), 'Stint 3': ('Soft', 13), 'Stint 4': ('Medium', 16)}
# ✅ Detected pit stops for driver 1: [np.int64(14), np.int64(29), np.int64(42)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 6), 'Stint 2': ('Medium', 18), 'Stint 3': ('Medium', 18), 'Stint 4': ('Hard', 15)}
# ✅ Detected pit stops for driver 817: [np.int64(7), np.int64(25), np.int64(43)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Soft', 16), 'Stint 3': ('Soft', 13), 'Stint 4': ('Medium', 17)}
# ✅ Detected pit stops for driver 154: [np.int64(12), np.int64(28), np.int64(41)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 16), 'Stint 3': ('Hard', 20), 'Stint 4': ('Soft', 11)}
# ✅ Detected pit stops for driver 830: [np.int64(11), np.int64(27), np.int64(47)]
# ✅ Driver 826 stint map: {'Stint 1': ('Medium', 16), 'Stint 2': ('Medium', 18), 'Stint 3': ('Soft', 10), 'Stint 4': ('Soft', 12)}
# ✅ Detected pit stops for driver 826: [np.int64(17), np.int64(35), np.int64(45)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 7), 'Stint 2': ('Hard', 22), 'Stint 3': ('Hard', 27)}
# ✅ Detected pit stops for driver 13: [np.int64(8), np.int64(30)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 8), 'Stint 2': ('Hard', 26), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 822: [np.int64(9), np.int64(35)]
# ✅ Driver 838 stint map: {'Stint 1': ('Soft', 9), 'Stint 2': ('Medium', 16), 'Stint 3': ('Medium', 16), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 838: [np.int64(10), np.int64(26), np.int64(42)]
# ✅ Driver 825 stint map: {'Stint 1': ('Medium', 12), 'Stint 2': ('Soft', 12), 'Stint 3': ('Soft', 14), 'Stint 4': ('Soft', 18)}
# ✅ Detected pit stops for driver 825: [np.int64(13), np.int64(25), np.int64(39)]
# ✅ Driver 828 stint map: {'Stint 1': ('Medium', 13), 'Stint 2': ('Medium', 16), 'Stint 3': ('Hard', 27)}
# ✅ Detected pit stops for driver 828: [np.int64(14), np.int64(30)]
# ✅ Driver 836 stint map: {'Stint 1': ('Medium', 11), 'Stint 2': ('Medium', 18), 'Stint 3': ('Soft', 12), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 836: [np.int64(12), np.int64(30), np.int64(42)]
# ✅ Driver 831 stint map: {'Stint 1': ('Medium', 10), 'Stint 2': ('Medium', 20), 'Stint 3': ('Hard', 17), 'Stint 4': ('Soft', 9)}
# ✅ Detected pit stops for driver 831: [np.int64(11), np.int64(31), np.int64(48)]
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 1), 'Stint 2': ('Medium', 15), 'Stint 3': ('Hard', 19), 'Stint 4': ('Soft', 16)}
# ✅ Detected pit stops for driver 807: [np.int64(2), np.int64(17), np.int64(36), np.int64(56)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 2), 'Stint 2': ('Soft', 12), 'Stint 3': ('Medium', 23), 'Stint 4': ('Soft', 19)}
# ✅ Detected pit stops for driver 815: [np.int64(3), np.int64(15), np.int64(38)]
# ✅ Driver 837 stint map: {'Stint 1': ('Medium', 12), 'Stint 2': ('Medium', 19), 'Stint 3': ('Hard', 13), 'Stint 4': ('Soft', 12)}
# ✅ Detected pit stops for driver 837: [np.int64(13), np.int64(32), np.int64(45)]
# ✅ Driver 832 stint map: {'Stint 1': ('Medium', 2), 'Stint 2': ('Hard', 18), 'Stint 3': ('Medium', 9)}
# ✅ Detected pit stops for driver 832: [np.int64(2), np.int64(21)]
# ✅ Driver 821 stint map: {'Stint 1': ('Soft', 8), 'Stint 2': ('Soft', 1)}
# ✅ Detected pit stops for driver 821: [np.int64(9)]
# ✅ Driver 18 stint map: {'Stint 1': ('Soft', 6)}
# ✅ Detected pit stops for driver 18: []
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 928...
# Compound map for this race: {'Supersoft': 'Supersoft', 'Super': 'Super', 'Soft': 'Soft', 'Medium': 'Medium', 'Hard': 'Hard'}
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 23)}
# ✅ Detected pit stops for driver 1: [np.int64(15), np.int64(34)]
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 16), 'Stint 3': ('Medium', 25)}
# ✅ Detected pit stops for driver 3: [np.int64(16), np.int64(32)]
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 17), 'Stint 3': ('Medium', 26)}
# ✅ Detected pit stops for driver 20: [np.int64(14), np.int64(31)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 8: [np.int64(16), np.int64(35)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 21), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 13: [np.int64(14), np.int64(35)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Medium', 21), 'Stint 3': ('Medium', 21)}
# ✅ Detected pit stops for driver 822: [np.int64(15), np.int64(36)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 20), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 154: [np.int64(13), np.int64(33)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 21), 'Stint 3': ('Medium', 25)}
# ✅ Detected pit stops for driver 831: [np.int64(11), np.int64(32)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 22), 'Stint 3': ('Medium', 20)}
# ✅ Detected pit stops for driver 817: [np.int64(15), np.int64(37)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 16), 'Stint 3': ('Medium', 25)}
# ✅ Detected pit stops for driver 828: [np.int64(15), np.int64(31)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Soft', 15), 'Stint 3': ('Soft', 15), 'Stint 4': ('Medium', 14)}
# ✅ Detected pit stops for driver 815: [np.int64(12), np.int64(27), np.int64(42)]
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 23), 'Stint 3': ('Soft', 20)}
# ✅ Detected pit stops for driver 4: [np.int64(13), np.int64(36)]
# ✅ Driver 18 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 18), 'Stint 3': ('Medium', 23)}
# ✅ Detected pit stops for driver 18: [np.int64(15), np.int64(33)]
# ✅ Driver 832 stint map: {'Stint 1': ('Medium', 19), 'Stint 2': ('Soft', 20), 'Stint 3': ('Soft', 16)}
# ✅ Detected pit stops for driver 832: [np.int64(20), np.int64(40)]
# ✅ Driver 829 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Medium', 22), 'Stint 3': ('Soft', 16)}
# ✅ Detected pit stops for driver 829: [np.int64(17), np.int64(39)]
# ✅ Driver 833 stint map: {'Stint 1': ('Soft', 17), 'Stint 2': ('Medium', 23), 'Stint 3': ('Soft', 14)}
# ✅ Detected pit stops for driver 833: [np.int64(18), np.int64(41)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 20), 'Stint 3': ('Medium', 20)}
# ✅ Detected pit stops for driver 830: [np.int64(13), np.int64(33)]
# ✅ Driver 813 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 22), 'Stint 3': ('Medium', 16)}
# ✅ Detected pit stops for driver 813: [np.int64(12), np.int64(33)]
# ✅ Driver 826 stint map: {'Stint 1': ('Medium', 15)}
# ✅ Detected pit stops for driver 826: []
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 9)}
# ✅ Detected pit stops for driver 807: []
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 929...
# Compound map for this race: {'Supersoft': 'Supersoft', 'Super': 'Super', 'Soft': 'Soft', 'Medium': 'Medium', 'Hard': 'Hard'}
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 18), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 1: [np.int64(16), np.int64(34)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 17), 'Stint 2': ('Medium', 23), 'Stint 3': ('Soft', 17)}
# ✅ Detected pit stops for driver 8: [np.int64(18), np.int64(41)]
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 20), 'Stint 3': ('Medium', 23)}
# ✅ Detected pit stops for driver 3: [np.int64(15), np.int64(35)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 822: [np.int64(15), np.int64(34)]
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 4), 'Stint 4': ('Medium', 21)}
# ✅ Detected pit stops for driver 20: [np.int64(14), np.int64(33), np.int64(37)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 817: [np.int64(15), np.int64(36)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 26)}
# ✅ Detected pit stops for driver 154: [np.int64(13), np.int64(32)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 17), 'Stint 2': ('Soft', 20), 'Stint 3': ('Medium', 19)}
# ✅ Detected pit stops for driver 815: [np.int64(18), np.int64(38)]
# ✅ Driver 826 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 19), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 826: [np.int64(16), np.int64(35)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Soft', 14), 'Stint 3': ('Medium', 32)}
# ✅ Detected pit stops for driver 13: [np.int64(11), np.int64(25)]
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 22), 'Stint 3': ('Soft', 21)}
# ✅ Detected pit stops for driver 4: [np.int64(14), np.int64(36)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Soft', 14), 'Stint 3': ('Soft', 17), 'Stint 4': ('Medium', 15)}
# ✅ Detected pit stops for driver 831: [np.int64(11), np.int64(25), np.int64(42)]
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Soft', 15), 'Stint 3': ('Medium', 13), 'Stint 4': ('Medium', 18)}
# ✅ Detected pit stops for driver 807: [np.int64(11), np.int64(26), np.int64(39)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Soft', 14), 'Stint 3': ('Soft', 12), 'Stint 4': ('Medium', 19)}
# ✅ Detected pit stops for driver 828: [np.int64(12), np.int64(26), np.int64(38)]
# ✅ Driver 813 stint map: {'Stint 1': ('Medium', 10), 'Stint 2': ('Soft', 14), 'Stint 3': ('Soft', 17), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 813: [np.int64(11), np.int64(25), np.int64(42)]
# ✅ Driver 829 stint map: {'Stint 1': ('Soft', 19), 'Stint 2': ('Soft', 14), 'Stint 3': ('Medium', 22)}
# ✅ Detected pit stops for driver 829: [np.int64(20), np.int64(34)]
# ✅ Driver 833 stint map: {'Stint 1': ('Soft', 18), 'Stint 2': ('Soft', 16), 'Stint 3': ('Medium', 20)}
# ✅ Detected pit stops for driver 833: [np.int64(19), np.int64(35)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 6), 'Stint 2': ('Medium', 24), 'Stint 3': ('Soft', 4)}
# ✅ Detected pit stops for driver 830: [np.int64(7), np.int64(31)]
# ✅ Driver 832 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 18)}
# ✅ Detected pit stops for driver 832: [np.int64(12)]
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 939...
# Compound map for this race: {'Supersoft': 'Soft', 'Super': 'Soft', 'Soft': 'Medium', 'Medium': 'Hard', 'Hard': 'Hard'}
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 24), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 20: [np.int64(16), np.int64(38)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 24), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 817: [np.int64(14), np.int64(38)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 24), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 8: [np.int64(14), np.int64(38)]
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 24), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 3: [np.int64(14), np.int64(38)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 24), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 822: [np.int64(14), np.int64(38)]
# ✅ Driver 826 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 28)}
# ✅ Detected pit stops for driver 826: [np.int64(13), np.int64(37)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 21), 'Stint 3': ('Medium', 27)}
# ✅ Detected pit stops for driver 815: [np.int64(14), np.int64(38)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Medium', 24), 'Stint 3': ('Soft', 25)}
# ✅ Detected pit stops for driver 830: [np.int64(13), np.int64(37)]
# ✅ Driver 832 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 18), 'Stint 3': ('Soft', 9), 'Stint 4': ('Soft', 24)}
# ✅ Detected pit stops for driver 832: [np.int64(13), np.int64(29), np.int64(38)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 21), 'Stint 3': ('Medium', 27)}
# ✅ Detected pit stops for driver 831: [np.int64(14), np.int64(38)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 18), 'Stint 3': ('Soft', 8), 'Stint 4': ('Medium', 25)}
# ✅ Detected pit stops for driver 828: [np.int64(13), np.int64(29), np.int64(37)]
# ✅ Driver 813 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Soft', 17), 'Stint 3': ('Medium', 27), 'Stint 4': ('Soft', 7)}
# ✅ Detected pit stops for driver 813: [np.int64(13), np.int64(28), np.int64(55)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 9), 'Stint 2': ('Medium', 17), 'Stint 3': ('Medium', 33)}
# ✅ Detected pit stops for driver 154: [np.int64(10), np.int64(27)]
# ✅ Driver 834 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 23), 'Stint 3': ('Soft', 23)}
# ✅ Detected pit stops for driver 834: [np.int64(14), np.int64(37)]
# ✅ Driver 829 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Medium', 23), 'Stint 3': ('Soft', 22)}
# ✅ Detected pit stops for driver 829: [np.int64(15), np.int64(38)]
# ✅ Driver 18 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 24), 'Stint 3': ('Medium', 4), 'Stint 4': ('Soft', 11)}
# ✅ Detected pit stops for driver 18: [np.int64(14), np.int64(38), np.int64(42)]
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 10), 'Stint 2': ('Medium', 23)}
# ✅ Detected pit stops for driver 4: [np.int64(13)]
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 19)}
# ✅ Detected pit stops for driver 1: [np.int64(14)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 12), 'Stint 2': ('Soft', 2), 'Stint 3': ('Medium', 15), 'Stint 4': ('Medium', 1)}
# ✅ Detected pit stops for driver 13: [np.int64(15), np.int64(15)]
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 11), 'Stint 2': ('Medium', 1)}
# ✅ Detected pit stops for driver 807: [np.int64(12)]
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 938...
# Compound map for this race: {'Supersoft': 'Supersoft', 'Super': 'Super', 'Soft': 'Soft', 'Medium': 'Medium', 'Hard': 'Hard'}
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 26), 'Stint 2': ('Medium', 27)}
# ✅ Detected pit stops for driver 1: [np.int64(27)]
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 25), 'Stint 2': ('Medium', 28)}
# ✅ Detected pit stops for driver 20: [np.int64(26)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 19), 'Stint 2': ('Medium', 34)}
# ✅ Detected pit stops for driver 13: [np.int64(20)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 22), 'Stint 2': ('Medium', 31)}
# ✅ Detected pit stops for driver 822: [np.int64(23)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 28), 'Stint 2': ('Medium', 25)}
# ✅ Detected pit stops for driver 8: [np.int64(29)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 23), 'Stint 2': ('Medium', 30)}
# ✅ Detected pit stops for driver 815: [np.int64(24)]
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 18), 'Stint 2': ('Medium', 34)}
# ✅ Detected pit stops for driver 807: [np.int64(19)]
# ✅ Driver 817 stint map: {'Stint 1': ('Medium', 30), 'Stint 2': ('Soft', 22)}
# ✅ Detected pit stops for driver 817: [np.int64(31)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 20), 'Stint 2': ('Medium', 32)}
# ✅ Detected pit stops for driver 828: [np.int64(21)]
# ✅ Driver 826 stint map: {'Stint 1': ('Medium', 27), 'Stint 2': ('Soft', 25)}
# ✅ Detected pit stops for driver 826: [np.int64(28)]
# ✅ Driver 832 stint map: {'Stint 1': ('Medium', 10), 'Stint 2': ('Soft', 20), 'Stint 3': ('Soft', 22)}
# ✅ Detected pit stops for driver 832: [np.int64(11), np.int64(31)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 19), 'Stint 2': ('Medium', 14), 'Stint 3': ('Soft', 19)}
# ✅ Detected pit stops for driver 830: [np.int64(20), np.int64(34)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 1), 'Stint 2': ('Medium', 23), 'Stint 3': ('Medium', 28)}
# ✅ Detected pit stops for driver 831: [np.int64(2), np.int64(25)]
# ✅ Driver 18 stint map: {'Stint 1': ('Soft', 25), 'Stint 2': ('Medium', 27)}
# ✅ Detected pit stops for driver 18: [np.int64(26)]
# ✅ Driver 829 stint map: {'Stint 1': ('Soft', 26), 'Stint 2': ('Medium', 25)}
# ✅ Detected pit stops for driver 829: [np.int64(27)]
# ✅ Driver 833 stint map: {'Stint 1': ('Soft', 27), 'Stint 2': ('Medium', 24)}
# ✅ Detected pit stops for driver 833: [np.int64(28)]
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 18), 'Stint 2': ('Medium', 32)}
# ✅ Detected pit stops for driver 3: [np.int64(19)]
# ✅ Driver 4 stint map: {'Stint 1': ('Medium', 28), 'Stint 2': ('Soft', 19)}
# ✅ Detected pit stops for driver 4: [np.int64(29)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 1)}
# ✅ Detected pit stops for driver 154: []
# ✅ Driver 813 stint map: {'Stint 1': ('Soft', 1)}
# ✅ Detected pit stops for driver 813: []
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 936...
# Compound map for this race: {'Supersoft': 'Supersoft', 'Super': 'Super', 'Soft': 'Soft', 'Medium': 'Medium', 'Hard': 'Hard'}
# ✅ Driver 20 stint map: {'Stint 1': ('Soft', 21), 'Stint 2': ('Soft', 22), 'Stint 3': ('Medium', 26)}
# ✅ Detected pit stops for driver 20: [np.int64(22), np.int64(47)]
# ✅ Driver 826 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Medium', 20), 'Stint 3': ('Soft', 36)}
# ✅ Detected pit stops for driver 826: [np.int64(14), np.int64(34)]
# ✅ Driver 817 stint map: {'Stint 1': ('Soft', 21), 'Stint 2': ('Medium', 21), 'Stint 3': ('Soft', 22), 'Stint 4': ('Soft', 5)}
# ✅ Detected pit stops for driver 817: [np.int64(22), np.int64(46), np.int64(65)]
# ✅ Driver 830 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 23), 'Stint 3': ('Medium', 9), 'Stint 4': ('Soft', 23)}
# ✅ Detected pit stops for driver 830: [np.int64(15), np.int64(38), np.int64(47)]
# ✅ Driver 4 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 7), 'Stint 4': ('Soft', 26)}
# ✅ Detected pit stops for driver 4: [np.int64(16), np.int64(37), np.int64(44)]
# ✅ Driver 1 stint map: {'Stint 1': ('Soft', 19), 'Stint 2': ('Soft', 23), 'Stint 3': ('Medium', 9), 'Stint 4': ('Soft', 18)}
# ✅ Detected pit stops for driver 1: [np.int64(20), np.int64(46), np.int64(52)]
# ✅ Driver 154 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 20), 'Stint 3': ('Medium', 8), 'Stint 4': ('Soft', 27)}
# ✅ Detected pit stops for driver 154: [np.int64(15), np.int64(35), np.int64(45)]
# ✅ Driver 3 stint map: {'Stint 1': ('Soft', 20), 'Stint 2': ('Medium', 22), 'Stint 3': ('Medium', 22), 'Stint 4': ('Soft', 5)}
# ✅ Detected pit stops for driver 3: [np.int64(21), np.int64(46), np.int64(65)]
# ✅ Driver 18 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 34)}
# ✅ Detected pit stops for driver 18: [np.int64(15), np.int64(36)]
# ✅ Driver 828 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Soft', 17), 'Stint 3': ('Medium', 8), 'Stint 4': ('Soft', 28)}
# ✅ Detected pit stops for driver 828: [np.int64(17), np.int64(34), np.int64(45)]
# ✅ Driver 831 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Soft', 18), 'Stint 3': ('Medium', 10), 'Stint 4': ('Soft', 27)}
# ✅ Detected pit stops for driver 831: [np.int64(15), np.int64(33), np.int64(45)]
# ✅ Driver 13 stint map: {'Stint 1': ('Soft', 14), 'Stint 2': ('Medium', 15), 'Stint 3': ('Soft', 25), 'Stint 4': ('Soft', 15)}
# ✅ Detected pit stops for driver 13: [np.int64(15), np.int64(30), np.int64(55)]
# ✅ Driver 822 stint map: {'Stint 1': ('Soft', 13), 'Stint 2': ('Soft', 25), 'Stint 3': ('Medium', 11), 'Stint 4': ('Soft', 20)}
# ✅ Detected pit stops for driver 822: [np.int64(14), np.int64(42), np.int64(50)]
# ✅ Driver 813 stint map: {'Stint 1': ('Medium', 25), 'Stint 2': ('Soft', 16), 'Stint 3': ('Soft', 28)}
# ✅ Detected pit stops for driver 813: [np.int64(26), np.int64(45)]
# ⚠️ Invalid stint data for driver 833 in Stint 4: Soft
# ✅ Driver 833 stint map: {'Stint 1': ('Soft', 6), 'Stint 2': ('Soft', 24), 'Stint 3': ('Medium', 37)}
# ✅ Detected pit stops for driver 833: [np.int64(7), np.int64(31)]
# ⚠️ Invalid stint data for driver 829 in Stint 4: Soft
# ✅ Driver 829 stint map: {'Stint 1': ('Soft', 26), 'Stint 2': ('Soft', 15), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 829: [np.int64(27), np.int64(44)]
# ✅ Driver 832 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 24)}
# ✅ Detected pit stops for driver 832: [np.int64(16), np.int64(37)]
# ✅ Driver 8 stint map: {'Stint 1': ('Soft', 22), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 9), 'Stint 4': ('Soft', 3)}
# ✅ Detected pit stops for driver 8: [np.int64(23), np.int64(47), np.int64(53)]
# ✅ Driver 815 stint map: {'Stint 1': ('Soft', 16), 'Stint 2': ('Soft', 14), 'Stint 3': ('Medium', 11), 'Stint 4': ('Soft', 12)}
# ✅ Detected pit stops for driver 815: [np.int64(17), np.int64(31), np.int64(45)]
# ✅ Driver 807 stint map: {'Stint 1': ('Soft', 15), 'Stint 2': ('Soft', 21), 'Stint 3': ('Medium', 5)}
# ✅ Detected pit stops for driver 807: [np.int64(16), np.int64(37)]
# ✅ `tyre_compound` and `tyre_age` successfully created.
# Processing Race ID 937...
# Compound map for this race: {'Supersoft': 'Supersoft', 'Super': 'Super', 'Soft': 'Soft', 'Medium': 'Medium', 'Hard': 'Hard'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/f1_rl/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'driverId'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[174], line 12
#       9 race_data = lap_times_copy.loc[lap_times_copy['raceId'] == int(race_id)].copy()
#      11 if not race_data.empty and not tyre_info.empty:
# ---> 12     result = assign_tyre_data(race_data, tyre_info)
#      13     if result is not None:
#      14         processed_data_by_race[race_id] = result
#
# Cell In[169], line 30, in assign_tyre_data(df, tyre_data, threshold)
#      27 print(f"Compound map for this race: {compound_map}")
#      29 # ✅ Step 3: Loop through each driver ID
# ---> 30 for driver_id in tyre_data['driverId'].unique():
#      31     driver_stints = tyre_data.loc[tyre_data['driverId'] == driver_id].iloc[0]
#      33     # ✅ Create a dictionary to hold stint info
#
# File /opt/anaconda3/envs/f1_rl/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/f1_rl/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'driverId'

# %%
# ✅ Export each race's data to a separate CSV file
output_dir = project_root/'processed_training_data'
os.makedirs(output_dir, exist_ok=True)

for race_id, data in processed_data_by_race.items():
    output_file = os.path.join(output_dir, f"{race_id}_training_data.csv")
    data.to_csv(output_file, index=False)
    print(f"✅ Training data for race {race_id} saved to {output_file}")
